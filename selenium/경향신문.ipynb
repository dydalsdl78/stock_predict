# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import selenium.common.exceptions
import time
import random
import re

result = []

options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-setuid-sandbox")
driver = webdriver.Chrome('C:/Users/Kimyongmin/프로젝트/chromedriver.exe', options=options)

url = "https://search.naver.com/search.naver?where=news&query=%EB%8C%80%ED%95%9C%ED%95%AD%EA%B3%B5&sm=tab_opt&sort=2&photo=0&field=0&reporter_article=&pd=3&ds=2014.05.01&de=2019.05.15&docid=&nso=so%3Ada%2Cp%3Afrom20140501to20190515%2Ca%3Aall&mynews=1&refresh_start={}&related=0"
driver.get(url)

driver.find_element_by_xpath("""//*[@id="news_popup"]/a""").click()
driver.find_element_by_xpath("""//*[@id="ca_1032"]""").click()
driver.find_element_by_xpath("""//*[@id="_nx_option_media"]/div[2]/div[3]/button[1]/span""").click()
driver.find_element_by_xpath("""//*[@id="nx_option_mson"]""").click()


for j in range(0, 330):
    url = "https://search.naver.com/search.naver?&where=news&query=%EB%8C%80%ED%95%9C%ED%95%AD%EA%B3%B5&sm=tab_pge&sort=2&photo=0&field=0&reporter_article=&pd=3&ds=2014.05.01&de=2019.05.01&docid=&nso=so:da,p:from20140501to20190501,a:all&mynews=1&start={}1&refresh_start=0"
    driver.get(url.format(j))
    
    
    atag_list = driver.find_elements_by_xpath("""//*[@class="type01"]//dt/a""")
    date_list = driver.find_elements_by_xpath("""//*[@class="type01"]//dd[1]""")
    media_list = driver.find_elements_by_xpath("""//*[@class="type01"]//dd[1]/span[1]""")
    
    a_ls = []
    d_ls = []
    t_ls = []
    m_ls = []
    for i in range(0, len(atag_list)) :
        a_ls.append(atag_list[i].get_attribute("href"))
        t_ls.append(atag_list[i].get_attribute("title"))
        d_ls.append(date_list[i].text)
        m_ls.append(media_list[i].text)


    for i in range(0, len(a_ls)) :
        item_url = a_ls[i]
        item_date = d_ls[i]
        item_title = t_ls[i]
        item_media = m_ls[i]
        
        driver.get(item_url)
        r=random.randint(2,3)
        time.sleep(r)
        
        p = re.compile('[0-9]+.[0-9]+.[0-9]+')
        date_ls = p.findall(item_date)
        date = ''.join(date_ls)
        
        
        
        try:
            Content_path = driver.find_element_by_xpath("""//*[@id="articleBody"]""")
            hangul = re.compile('[^ ㄱ-ㅣ가-힣a-zA-Z0-9.]+')
            content=hangul.sub('', Content_path.text)
            
            result.append([item_media, date, item_title, item_url, content])

            driver.back()
            r=random.randint(2,3)
            time.sleep(r)

        except :
            driver.back()
            print("Selenium Common Eerror")
            pass

# %%
import pandas as pd
x=pd.DataFrame(result, columns=['media','date','title','url','content'])

# %%
x
# Out:
#   media        date                             title  \
# 0  경향신문  2019.04.30           [경제와 세상]포용성장 2년의 성과와 한계
# 1  경향신문  2019.04.30              오늘의 부고 - 2019년 5월 1일
# 2  경향신문  2019.04.30           ‘칼피아’ 비판받고도 구태 못 버린 국토부
# 3  경향신문  2019.05.01  대한항공, 국제선 70%에서 ‘일등석’ 없앤다…효율화 전략
# 4  경향신문  2019.05.01            대한항공 ‘텅텅 비는’ 일등석 확 줄인다
#
#                                                  url  \
# 0  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 1  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 2  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 3  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 4  http://news.khan.co.kr/kh_news/khan_art_view.h...
#
#                                              content
# 0  문재인 정부는 소득주도성장과 혁신성장 공정경제 정책을 추진하고 있다. 양극화와 불평...
# 1  김창진씨 별세 현하은하전하희정씨성현 LG디스플레이 전무 부친상 조미화씨 시부상4월3...
# 2  항공청 직원들 좌석 승급 혜택항공사 라운지 공짜 이용 여전항공사에서 제공하는 라운지...
# 3  대한항공이 오는 6월부터 국제선 27개 노선의 일등석을 없애기로 했다. 기존 일등석...
# 4  국제선 27개 노선 수익성 제고 위해 6월1일부터 좌석 체계 개편대한항공이 오는 6...
